# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushikhandelwal99/ML/blob/ml/computer_vision1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img1=cv2.imread('cat1.jpg')[0:183,0:267]
img2=cv2.imread('cat2.jpg')[0:183,0:267]
img3=cv2.imread('dog1.jpg')

# %%
a=np.zeros([183,267,3])
b=np.zeros([183,267,3])

# %%
a[0:,130:]=img2[0:,130:]
a[0:,0:130]=img1[0:,0:130]

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FAAB76EF7F0>

# %%
b[0:,0:130]=img2[0:,0:130]
b[0:,130:]=img1[0:,130:]

# %%
c=cv2_imshow(b)
c
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FAAAEEDF710>

# %%
b[85:95,120:140]=img3[85:95,120:140]
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FAAAEEDF8D0>
