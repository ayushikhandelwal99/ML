# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushikhandelwal99/ML/blob/master/Web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://en.wikipedia.org/wiki/ML_(programming_language)"

# %%
#we are sending request to the url and taking the response
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>ML (programming language) - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"ML_(programming_language)","wgTitle":"ML (programming language)","wgCurRevisionId":895915090,"wgRevisionId":895915090,"wgArticleId":20607,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles needing additional references from May 2015","All articles needing additional references","All articles with unsourced statements","Articles with unsourced statements from January 2019","Articles with unsourced statements from May 2015","Articles with unsourced statements from August 2010","Academic programming languages","Functional languages","Procedur
# ...

# %%
#parsing library - html.parser and second is lxml
soup = BeautifulSoup(response.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>ML (programming language) - Wikipedia</title>
# ...

# %%
for Alink in soup.find_all('a'):
  #print(Alink)

  print(Alink.get('href'))
# Out:
# None
# #mw-head
# #p-search
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Verifiability
# //en.wikipedia.org/w/index.php?title=ML_(programming_language)&action=edit
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1
# //www.google.com/search?as_eq=wikipedia&q=%22ML%22+programming+language
# //www.google.com/search?tbm=nws&q=%22ML%22+programming+language+-wikipedia
# //www.google.com/search?&q=%22ML%22+programming+language+site:news.google.com/newspapers&source=newspapers
# //www.google.com/search?tbs=bks:1&q=%22ML%22+programming+language+-wikipedia
# //scholar.google.com/scholar?q=%22ML%22+programming+language
# https://www.jstor.org/action/doBasicSearch?Query=%22ML%22+programming+language&acc=on&wc=on
# /wiki/Help:Maintenance_template_removal
# /wiki/Programming_paradigm
# /wiki/Multi-paradigm_programming_language
# /wiki/Functional_programming
# /wiki/Imperative_programming
# /wiki/Software_design
# /wiki/Robin_Milner
# /wiki/University_of_Edinburgh
# ...

# %%
for ptag in soup.find_all('p'):
  #print(ptag)
  for btag in ptag.find_all('b'):
    print(btag.text)
# Out:
# ML

# %%
import pandas as pd

# %%
a=['ayushi',20,56]
b=['aditi',20,64]
c=['smriti',19,74]
df = pd.DataFrame([a,b,c],columns=['name','age','marks'])

# %%
df
# Out:
#      name  age  marks
# 0  ayushi   20     56
# 1   aditi   20     64
# 2  smriti   19     74
