# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushikhandelwal99/ML/blob/ml/computer_vision3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img1=cv2.imread('cat1.jpg')[0:183,:]
img2=cv2.imread('cat2.jpg')[:,0:267]

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FDB3D13EE48>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FDB3D05E470>

# %%
cv2_imshow(img2-img1)
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FDB3D05E438>

# %%
cv2_imshow(img1-img2)
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FDB45870780>

# %%
cv2_imshow(img1+img2)
# Out:
# <PIL.Image.Image image mode=RGB size=267x183 at 0x7FDB3D05E668>
